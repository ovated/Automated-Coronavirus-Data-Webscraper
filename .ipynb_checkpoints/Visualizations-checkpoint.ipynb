# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("CORONA_VIRUS_DATA.csv")
# df['DATE'] = pd.to_datetime(df["DATE"])
df.head()
# Out:
#    Unnamed: 0       DATE  CONFIRMED_CASES  ACTIVE_CASES  DEATHS
# 0           0  2/28/2020                1             1       0
# 1           1  2/29/2020                1             1       0
# 2           2   3/1/2020                1             1       0
# 3           3   3/2/2020                1             1       0
# 4           4   3/3/2020                1             1       0

# %%
df["DATE"] = pd.to_datetime(df["DATE"])

# %%
from datetime import datetime as dt

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(y = df['DEATHS'], x = df['DATE'])
# sns.lineplot(y = df['CONFIRMED_CASES'], x = df['DATE'].dt.month)
sns.lineplot()
# plt.xlabel("Date")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='DEATHS'>

# %%
plt.figure(figsize=(16, 6))
sns.lineplot(y = df['CONFIRMED_CASES'], x = df['DATE'].dt.month)
sns.lineplot()
# plt.xlabel("Date")
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='CONFIRMED_CASES'>
